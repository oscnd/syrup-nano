# %%
from pathlib import Path
import sys
import os

# %%
from src.nano import Nano
from src.tokenizer import WordEncodeResult

# %%
nano = Nano()

# %%
lorem = "Lorem ipsum dolor sit amet, consectetur adipiscing elit." \
    "\nSed do eiusmod tempor incididunt ut labore et dolore magna aliqua."
result = nano.encode(lorem)
parsed = WordEncodeResult(result)
parsed.to_list()

# %%
parsed.to_token_list()

# %%
lorem = "// * database.P()"
result = nano.encode(lorem)
parsed = WordEncodeResult(result)
parsed.to_list()
