# %%
import ctypes

# Load the shared library
lib = ctypes.CDLL('../nano.so')

# Define argument and return types
lib.encode.argtype = ctypes.c_char_p
lib.encode.restype = ctypes.c_char_p

# Call the Go function
result = lib.encode(b"Hello").decode('utf-8')
print(result)
